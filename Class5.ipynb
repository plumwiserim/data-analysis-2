# %% [markdown]
# <a href="https://colab.research.google.com/github/plumwiserim/Data-Analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 데이터 분석을 위한 Pandas 라이브러리 활용

# %% [markdown]
# ## 데이터 시각화를 위한 파이썬 라이브러리

# %%
import seaborn as sns

anscombe_df = sns.load_dataset("anscombe")
print(anscombe_df)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
print(type(anscombe_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
categorical = anscombe_df.dataset.unique()
categorical
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
dataset_1 = anscombe_df[anscombe_df['dataset'] == categorical[0]]
dataset_2 = anscombe_df[anscombe_df['dataset'] == categorical[1]]
dataset_3 = anscombe_df[anscombe_df['dataset'] == categorical[2]]
dataset_4 = anscombe_df[anscombe_df['dataset'] == categorical[3]]

# 임의의 데이터셋 출력해보기
print(dataset_3)
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %%
dataset_1.describe()
dataset_2.describe()
dataset_3.describe()
dataset_4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# ## Matplotlib 라이브러리

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('some numbers')
plt.show()

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.ylabel('some numbers')
plt.show()

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'g-o')
plt.ylabel('some numbers')
plt.show()

# %%
plt.figure()
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.xlim([0, 5])
plt.ylim([0, 20])
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervalse
t = np.arange(0., 5., 0.2)

plt.figure(figsize=(8,4))

plt.plot(t, t, 'r--')
plt.plot(t, t**2, 'bs')
plt.plot(t, t**3, 'g^')

plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervalse
t = np.arange(0., 5., 0.2)

plt.figure(figsize=(8,4))

plt.plot(t, t, 'r--')
plt.plot(t, t**2, 'bs')
plt.plot(t, t**3, 'g^')

plt.title('Plot Test')
plt.xlabel('x_data')
plt.ylabel('y_data')
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervalse
t = np.arange(0., 5., 0.2)

plt.figure(figsize=(8,4))

plt.plot(t, t, 'r--', label = 'a')
plt.plot(t, t**2, 'bs', label = 'b')
plt.plot(t, t**3, 'g^', label = 'c')

plt.title('Plot Test')
plt.xlabel('x_data')
plt.ylabel('y_data')

plt.legend()
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervalse
t = np.arange(0., 5., 0.2)

plt.figure(figsize=(8,4))

plt.plot(t, t, 'r--', label = 'a')
plt.plot(t, t**2, 'bs', label = 'b')
plt.plot(t, t**3, 'g^', label = 'c')

plt.title('Plot Test')
plt.xlabel('x_data')
plt.ylabel('y_data')

plt.legend()
# plt.show()

plt.savefig('test.png', dpi=100, bbow_inches='tight')

# %%
plt.bar(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8369282d1a78> in <module>()
# ----> 1 plt.bar(x,y)
#       2 plt.show()
#
# NameError: name 'x' is not defined

# %%
colors = ['yellowgreen', 'lightskyblue', 'lightcoral']

plt.pie(y, labels = x, colors = colors, 
        autopct='%1.1f%%', startangle=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-45c86cc4e1c7> in <module>()
#       1 colors = ['yellowgreen', 'lightskyblue', 'lightcoral']
#       2
# ----> 3 plt.pie(y, labels = x, colors = colors,
#       4         autopct='%1.1f%%', startangle=90)
#       5 plt.show()
#
# NameError: name 'y' is not defined

# %%
Classes = ['A', 'B', 'C', 'D', 'E']
men = [50, 45, 58, 22, 49]
women = [38, 92, 50, 37, 15]

x = range(len(men))
plt.bar(x, men)
plt.bar(x, women, bottom=men)

plt.legen(['Male', 'Female'])
ax = plt.subplot()
ax.set_xticks(range(len(Classes)))
ax.set_xticklabels(Classes)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-ecbe00099f46> in <module>()
#       7 plt.bar(x, women, bottom=men)
#       8
# ----> 9 plt.legen(['Male', 'Female'])
#      10 ax = plt.subplot()
#      11 ax.set_xticks(range(len(Classes)))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'legen'

# %%
plt.hist(boston_df['price'], bins=10)
plt.xlabel('Price', fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b9156c93f735> in <module>()
# ----> 1 plt.hist(boston_df['price'], bins=10)
#       2 plt.xlabel('Price', fontsize=14)
#       3 plt.show()
#
# NameError: name 'boston_df' is not defined

# %%
# 산점도 그리기
plt.scatter(x='RM',y='price',data=boston_df)
plt.xlabel('RM',fontsize=14)
plt.ylabel('Price',fontsize=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8985e15a5312> in <module>()
#       1 # 산점도 그리기
# ----> 2 plt.scatter(x='RM',y='price',data=boston_df)
#       3 plt.xlabel('RM',fontsize=14)
#       4 plt.ylabel('Price',fontsize=1)
#       5 plt.show()
#
# NameError: name 'boston_df' is not defined

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')
plt.show()

# %%
plt.figure()

# %%
plt.subplot(221)
plt.subplot(222)
plt.subplot(223)
plt.subplot(224)

plt.show()

# %%
plt.subplot(131)
plt.subplot(132)
plt.subplot(133)

plt.show()

# %%
plt.subplot(221)
plt.plot(dataset_1['x'], dataset_1['y'], 'o')
plt.title('dataset_1')

plt.subplot(222)
plt.subplot(223)
plt.subplot(224)

plt.show()

# %%
plt.subplot(221)
plt.plot(dataset_1['x'], dataset_1['y'], 'o')
plt.title('dataset_1')

plt.subplot(222)
plt.plot(dataset_2['x'], dataset_2['y'], 'o')
plt.title('dataset_2')

plt.subplot(223)
plt.plot(dataset_3['x'], dataset_3['y'], 'o')
plt.title('dataset_3')

plt.subplot(224)
plt.plot(dataset_4['x'], dataset_4['y'], 'o')
plt.title('dataset_4')

plt.show()

# %%
plt.subplot(221)
plt.plot(dataset_1['x'], dataset_1['y'], 'o')
plt.title('dataset_1')

plt.subplot(222)
plt.plot(dataset_2['x'], dataset_2['y'], 'o')
plt.title('dataset_2')

plt.subplot(223)
plt.plot(dataset_3['x'], dataset_3['y'], 'o')
plt.title('dataset_3')

plt.subplot(224)
plt.plot(dataset_4['x'], dataset_4['y'], 'o')
plt.title('dataset_4')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 데이터 시각화를 위한 파이썬 라이브러리 Seaborn

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips = sns.load_dataset('tips')
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure()
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
plt.figure()
sns.scatterplot(x="total_bill", y="tip", hue="smoker", data=tips)
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="tip", data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="tip", palette="Blues", data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="smoker", style = "smoker", data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", hue="day", style="time", size="size", data=tips)

# %%
df = pd.DataFrame(dict(time=np.arange(500),
                       value=np.random.randn(500).cumsum()))
print(df)
# Out:
#      time     value
# 0       0  0.031051
# 1       1 -0.147101
# 2       2 -0.812549
# 3       3 -0.818711
# 4       4  0.039580
# ..    ...       ...
# 495   495  0.642230
# 496   496 -0.169836
# 497   497 -0.715694
# 498   498 -3.675269
# 499   499 -3.205963
#
# [500 rows x 2 columns]

# %%
sns.lineplot(x="time", y="value", data=df)
plt.show()

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
sns.relplot(x="time", y="value", data=df, kind="line")

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri)

# %%
sns.relplot(x="timepoint", y="signal", kind="line", estimator=None, data=fmri)

# %%
sns.relplot(x="timepoint", y="signal", kind="line", ci=None, data=fmri)

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event", kind="line", data=fmri)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips)

# %%
sns.relplot(x="timepoint", y="signal", hue="subject", 
            col="region", row="event", height=3, 
            estimator=None, kind="line", data=fmri)

# %%
sns.lmplot(x='RM', y='price', data=boston_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-95536c660d3b> in <module>()
# ----> 1 sns.lmplot(x='RM', y='price', data=boston_df)
#
# NameError: name 'boston_df' is not defined

# %%
sns.lmplot(x='RM', y='price', hue='CHAS", data=boston_df)
# Out:
#   File "<ipython-input-68-5186107f9454>", line 1
#     sns.lmplot(x='RM', y='price', hue='CHAS", data=boston_df)
#                                                              ^
# SyntaxError: EOL while scanning string literal

# %%
sns.lmplot(x='RM', y='price', hue='CHAS", col='CHAS', data=boston_df)
# Out:
#   File "<ipython-input-69-9de4c837048b>", line 1
#     sns.lmplot(x='RM', y='price', hue='CHAS", col='CHAS', data=boston_df)
#                                                       ^
# SyntaxError: invalid syntax

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.catplot(x="", y="", hue="", kind="bar", data=titanic)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-2d851593d5c3> in <module>()
# ----> 1 sns.catplot(x="", y="", hue="", kind="bar", data=titanic)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3787     p = _CategoricalPlotter()
#    3788     p.require_numeric = plotter_class.require_numeric
# -> 3789     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3790     if (
#    3791         order is not None
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input ''

# %%
sns.catplot(x="class", y="survived", hue="sex", kind="bar", data=titanic)

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)

# %%
flights_df = sns.load_dataset('flights')
flights_df.sample(5)
# Out:
#      year month  passengers
# 29   1951   Jun         178
# 123  1959   Apr         396
# 49   1953   Feb         196
# 8    1949   Sep         136
# 2    1949   Mar         132

# %%
result_df=flights_df.pivot('month', 'year', 'passengers')
result_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(result_df)
plt.show()

# %%
sns.heatmap(result_df, annot=True, fmt='d')
plt.show()

# %%
data=pd.read_csv("./pima-indians-diabetes-insertc.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-78-742ac2db3adc> in <module>()
# ----> 1 data=pd.read_csv("./pima-indians-diabetes-insertc.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: './pima-indians-diabetes-insertc.csv'

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-6208d269f320> in <module>()
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
data.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-c44ded798807> in <module>()
# ----> 1 data.corr()
#
# NameError: name 'data' is not defined

# %%
plt.figure(figsize=(12,12))

sns.heatmap(data.corr(), linewidths=0.1, vamx=0.5, 
            cmap='autumn', linecolor='white', annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-681d9e9226c5> in <module>()
#       1 plt.figure(figsize=(12,12))
#       2
# ----> 3 sns.heatmap(data.corr(), linewidths=0.1, vamx=0.5,
#       4             cmap='autumn', linecolor='white', annot=True)
#
# NameError: name 'data' is not defined
